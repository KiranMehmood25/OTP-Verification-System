# %%
import random
import smtplib
from email.mime.text import MIMEText
import tkinter as tk
from tkinter import messagebox

def generate_otp():
    return random.randint(100000, 999999)

def send_email(receiver_email, otp):
    sender_email = "k25402mehmood@gmail.com" 
    sender_password = "mfzlkumkdhptpeyq"       # Replace with your app-specific password

    message = MIMEText(f"Your OTP is: {otp}")
    message['Subject'] = "Your OTP Verification"
    message['From'] = sender_email
    message['To'] = receiver_email

    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, message.as_string())
        messagebox.showinfo("Info", "OTP sent to your email")
    except smtplib.SMTPException as e:
        messagebox.showerror("SMTP Error", f"SMTP error occurred: {e}")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred: {e}")

def verify_otp():
    user_otp = otp_entry.get()
    if user_otp == str(otp):
        messagebox.showinfo("Success", "OTP Verified Successfully!")
    else:
        messagebox.showerror("Error", "Invalid OTP")

otp = generate_otp()

root = tk.Tk()
root.title("OTP Verification")
root.geometry("400x250")  
root.configure(bg='white')

email_label = tk.Label(root, text="Enter your Email:", bg='light gray', fg='blue')
email_label.pack()
email_entry = tk.Entry(root)
email_entry.pack()

otp_label = tk.Label(root, text="Enter OTP:", bg='white', fg='blue')
otp_label.pack()
otp_entry = tk.Entry(root)
otp_entry.pack()

verify_button = tk.Button(root, text="Verify OTP", command=verify_otp, bg='green', fg='white')
verify_button.pack()

def send_otp():
    email = email_entry.get()
    send_email(email, otp)

send_otp_button = tk.Button(root, text="Send OTP", command=send_otp, bg='orange', fg='white')
send_otp_button.pack()

root.mainloop()
